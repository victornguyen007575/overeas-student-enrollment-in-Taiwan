# %% [markdown]
# # Overseas Student Enrollment in Taiwan: Data Wrangling & Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fuzzywuzzy import process
from utils import prepareData, plotTop10
from config import *

files = [file113, file112, file103To111] # 3 files including data in years 103-113 (2014-2024)

df = prepareData(files)
plotTop10(df)
